# %%
# !ls
# Out:
# betterhome.ipynb       orangepage.ipynb
# betterhome_recipe.zip  orangepage_recipe_20191219.zip

# %%
# !unzip orangepage_recipe_20191219.zip
# Out:
# Archive:  orangepage_recipe_20191219.zip
#    creating: orangepage_recipe/
#   inflating: orangepage_recipe/detail_100002.json
#   inflating: orangepage_recipe/detail_100003.json
#   inflating: orangepage_recipe/detail_100004.json
#   inflating: orangepage_recipe/detail_100005.json
#   inflating: orangepage_recipe/detail_100006.json
#   inflating: orangepage_recipe/detail_100008.json
#   inflating: orangepage_recipe/detail_100009.json
#   inflating: orangepage_recipe/detail_100034.json
#   inflating: orangepage_recipe/detail_100035.json
#   inflating: orangepage_recipe/detail_100036.json
#   inflating: orangepage_recipe/detail_100037.json
#   inflating: orangepage_recipe/detail_100039.json
#   inflating: orangepage_recipe/detail_100040.json
#   inflating: orangepage_recipe/detail_100041.json
#   inflating: orangepage_recipe/detail_100042.json
#   inflating: orangepage_recipe/detail_100050.json
#   inflating: orangepage_recipe/detail_100051.json
# ...

# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
_LOG_DIR = './orangepage_recipe'

# %%
def read_json_strings(filepath):
    with open(filepath, 'r', encoding='utf-8') as r:
        data = json.load(r)
    return data

# %%
def fetch_nest_dictkey(dic):
    for key, value in dic.items():
        yield key
        if isinstance(value, dict):
            yield from fetch_nest_dictkey(value)

# %%
json_col = []
count = 0
for f in os.listdir(_LOG_DIR):
    if os.path.isdir(os.path.join(_LOG_DIR, f)):
        pass
    else:
        try:
            tmp = read_json_strings(os.path.join(_LOG_DIR, f))
            count += 1
            json_col.append(tmp)
        except json.decoder.JSONDecodeError:
            pass
count
# Out:
# 15499

# %%
json_col[:5]
# Out:
# [{'title': '白菜としょうがのスープ',
#   'url': 'https://www.orangepage.net/recipes/detail_130639',
#   'recipe': '白菜は葉としんに切り分け、それぞれ一口大に切る。\n鍋に水1と1/2カップを煮立て、スープの素をくずしながら入れる。溶けたら、しょうが、白菜のしんを加え、2～3分煮る。白菜のしんが柔らかくなったら葉を加えてひと煮し、塩、こしょう各少々で味をととのえ、ごま油小さじ1/2を回し入れる。\n',
#   'time': '25',
#   'calory': '204kcal（1人分）',
#   'salt': '3.2g（1人分）',
#   'ingredients': {'材料': '2人分',
#    '白菜の葉': '2枚（200g）',
#    'しょうがのせん切り': '大1かけ分',
#    '洋風スープの素（チキン・固形）': '1個',
#    '塩': 'こしょう'},
#   'imageurl': 'https://production-orp.s3.amazonaws.com/uploads/recipes/image/0000130639/20131003152523_w300hf.jpg'},
#  {'title': 'えびとベーコンのピラフ',
#   'url': 'https://www.orangepage.net/recipes/detail_112811',
# ...

# %%
all_json_col = {
    'json_col': json_col
}

# %%
df = pd.DataFrame(json_col)

# %%
df.head()
# Out:
#            title                                               url  \
# 0    白菜としょうがのスープ  https://www.orangepage.net/recipes/detail_130639
# 1    えびとベーコンのピラフ  https://www.orangepage.net/recipes/detail_112811
# 2        ソーセージパイ  https://www.orangepage.net/recipes/detail_120318
# 3  新玉ねぎときぬさやのみそ汁  https://www.orangepage.net/recipes/detail_300848
# 4  かぼちゃのガーリックソテー  https://www.orangepage.net/recipes/detail_102567
#
#                                               recipe time        calory  \
# 0  白菜は葉としんに切り分け、それぞれ一口大に切る。\n鍋に水1と1/2カップを煮立て、スープの...   25  204kcal（1人分）
# 1  米は炊く30分前にといでざるに上げ、水けをきってよく乾かしておく。えびは竹串で背わたを取り除...   30  577kcal（1人分）
# 2  オーブンを180℃に温めはじめる。ソーセージは包丁で斜めに3本切り込みを入れる。冷凍パイシー...   15  472kcal（1人分）
# 3  新玉ねぎは2cm四方に切る。きぬさやはへたと筋を取り、大きければ斜め半分に切る。\n鍋にだし...   20  361kcal（1人分）
# 4  かぼちゃは厚さ4～5mmのくし形に切り、塩を加えた湯で柔らかくゆでて、水けをきる。にんにくは...  NaN           NaN
#
#         salt                                        ingredients  \
# ...

# %%
len(df['title'])
# Out:
# 15499

# %%
# !ls orangepage_recipe | wc -l
# Out:
# 15501

# %%
df['recipe_length'] = df['recipe'].apply(lambda x : len(x))

# %%
df['recipe_length'].head()
# Out:
# 0    141
# 1    343
# 2    272
# 3    110
# 4    143
# Name: recipe_length, dtype: int64

# %%
df['recipe_length'].count()
# Out:
# 15499

# %%
# レシピ文字数のヒストグラム
sns.distplot(df['recipe_length'], bins=100)
plt.show()

# %%
df['recipe_length'].describe()
# Out:
# count    15499.000000
# mean       282.785276
# std        156.123719
# min          1.000000
# 25%        174.000000
# 50%        259.000000
# 75%        358.000000
# max       1889.000000
# Name: recipe_length, dtype: float64

# %%
# 有効な調理時間の記載のあるレシピ数
df['time'].count()
# Out:
# 13051

# %%
type(df['time'][0])
# Out:
# str

# %%
# 調理時間のヒストグラム
df_time = df['time'].dropna().apply(lambda x: int(x)).sort_values()
sns.distplot(df_time)
plt.xticks(np.arange(0, 250+1, 25))
plt.show()

# %%
df_time.describe()
# Out:
# count    13051.000000
# mean        21.830128
# std          8.809914
# min          0.000000
# 25%         15.000000
# 50%         20.000000
# 75%         25.000000
# max        210.000000
# Name: time, dtype: float64

# %%
df['calory'].count()
# Out:
# 12981

# %%
df['calory'][0].split('kcal')[0]
# Out:
# '204'

# %%
calory = df['calory'].dropna()

# %%
len(calory)
# Out:
# 12981

# %%
calory_type = calory.apply(lambda x: type(x))

# %%
calory_type.unique()
# Out:
# array([<class 'str'>], dtype=object)

# %%
calory_value = calory.apply(lambda x : int(x.split('kcal')[0]))

# %%
calory_value.head()
# Out:
# 0    204
# 1    577
# 2    472
# 3    361
# 5    569
# Name: calory, dtype: int64

# %%
# カロリーの分布
sns.distplot(calory_value)
plt.show()

# %%
calory_value.describe()
# Out:
# count    12981.000000
# mean       325.433865
# std        166.486428
# min         13.000000
# 25%        203.000000
# 50%        313.000000
# 75%        431.000000
# max        901.000000
# Name: calory, dtype: float64

# %%
df['salt'].count()
# Out:
# 12877

# %%
df_salt = df['salt'].dropna()
df_salt_value = df_salt.apply(lambda x: float(x.split('g')[0]))
df_salt_value.head()
# Out:
# 0    3.2
# 1    4.8
# 2    2.1
# 3    2.3
# 5    3.9
# Name: salt, dtype: float64

# %%
# 塩分の分布
sns.distplot(df_salt_value)
plt.show()

# %%
df_salt_value.describe()
# Out:
# count    12877.000000
# mean         2.203852
# std          0.957931
# min          0.000000
# 25%          1.600000
# 50%          2.100000
# 75%          2.800000
# max          6.600000
# Name: salt, dtype: float64

# %%
df['ingredients'][9]
# Out:
# {'材料': '4人分',
#  'たね': {'豚ひき肉': '300g',
#   'しょうがの絞り汁': '小さじ1',
#   '酒': '大さじ1',
#   'しょうゆ': '大さじ1',
#   'みそ': '小さじ1',
#   '砂糖': '小さじ1'},
#  '油揚げ': '2枚',
#  '青じその葉': '8枚',
#  'しし唐辛子': '8～10本',
#  'しょうがの甘酢漬け': '適宜',
#  'たれ': {'しょうゆ': '大さじ1', '酒': '大さじ1', '砂糖': '小さじ1', 'みりん': '小さじ1'},
#  '片栗粉': ''}

# %%
type(df['ingredients'][0])
# Out:
# dict

# %%
len(df['ingredients'][9])
# Out:
# 8

# %%
a = list(fetch_nest_dictkey(df['ingredients'][9]))

# %%
a
# Out:
# ['材料',
#  'たね',
#  '豚ひき肉',
#  'しょうがの絞り汁',
#  '酒',
#  'しょうゆ',
#  'みそ',
#  '砂糖',
#  '油揚げ',
#  '青じその葉',
#  'しし唐辛子',
#  'しょうがの甘酢漬け',
#  'たれ',
#  'しょうゆ',
#  '酒',
#  '砂糖',
#  'みりん',
#  '片栗粉']

# %%
len(a)
# Out:
# 18

# %%
df['ingredients'].count()
# Out:
# 15499

# %%
count_ingredients = df['ingredients'].apply(lambda x: len(list(fetch_nest_dictkey(x))) - 1)

# %%
count_ingredients.head()
# Out:
# 0     4
# 1    11
# 2     5
# 3     4
# 4     6
# Name: ingredients, dtype: int64

# %%
# 食材の数
sns.distplot(count_ingredients)
plt.show()

# %%
count_ingredients.describe()
# Out:
# count    15499.000000
# mean         8.907091
# std          4.273525
# min          0.000000
# 25%          6.000000
# 50%          8.000000
# 75%         11.000000
# max         35.000000
# Name: ingredients, dtype: float64
